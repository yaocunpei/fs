# %%
# %run federatedscope/main.py --cfg federatedscope\gfl\baseline\fedavg_gin_minibatch_on_cikmcup.yaml  --client_cfg federatedscope/gfl/baseline/fedavg_gin_minibatch_on_cikmcup_per_client.yaml
# Out:
# 2022-09-09 09:42:12,174 (utils:129)INFO: the current machine is at 10.77.112.1
# 2022-09-09 09:42:12,177 (utils:131)INFO: the current dir is F:\python\FederatedScope
# 2022-09-09 09:42:12,178 (utils:132)INFO: the output dir is exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# 2022-09-09 09:42:13,844 (cikm_cup:57)INFO: Loading CIKMCUP data from F:\python\FederatedScope\data\CIKM22Competition.
# 2022-09-09 09:42:13,846 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #1.
# 2022-09-09 09:42:14,210 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #2.
# 2022-09-09 09:42:14,242 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #3.
# 2022-09-09 09:42:14,648 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #4.
# 2022-09-09 09:42:14,664 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #5.
# 2022-09-09 09:42:14,711 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #6.
# 2022-09-09 09:42:15,023 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #7.
# 2022-09-09 09:42:15,461 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #8.
# 2022-09-09 09:42:15,648 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #9.
# 2022-09-09 09:42:55,175 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #10.
# 2022-09-09 09:43:26,233 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #11.
# 2022-09-09 09:43:28,918 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #12.
# 2022-09-09 09:43:29,044 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #13.
# 2022-09-09 09:43:49,603 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.0
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: node
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:49,899 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-09-09 09:43:49,915 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.263789
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:49,932 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-09-09 09:43:49,947 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.289617
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:49,959 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-09-09 09:43:49,972 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.355404
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:49,988 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-09-09 09:43:50,004 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.176471
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,012 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-09-09 09:43:50,026 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.396825
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,037 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-09-09 09:43:50,052 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.26158
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.0005
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,067 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-09-09 09:43:50,082 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.302378
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,099 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-09-09 09:43:50,112 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.211538
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,126 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-09-09 09:43:50,141 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.059199
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,159 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-09-09 09:43:50,173 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.007083
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 10
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,186 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-09-09 09:43:50,204 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.734011
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 10
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-09 09:43:50,216 (fed_runner:302)INFO: Client 11 has been set up ...
# 2022-09-09 09:43:50,229 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 2
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 1.361326
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.0001_lstep10_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   use: False
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: -1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212
# personalization:
#   K: 13
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 10
#   lr: 0.0001
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# ...
# 2022-09-11 08:08:15,769 (client:259)INFO: {'Role': 'Client #3', 'Round': 105, 'Results_raw': {'train_avg_loss': 0.566091, 'train_total': 22190, 'train_imp_ratio': 20.217232, 'train_loss': 12561.55705}}
# 2022-09-11 08:08:18,141 (client:259)INFO: {'Role': 'Client #12', 'Round': 105, 'Results_raw': {'train_avg_loss': 0.863291, 'train_total': 6080, 'train_imp_ratio': 36.584571, 'train_loss': 5248.807399}}
# 2022-09-11 08:19:31,206 (client:259)INFO: {'Role': 'Client #9', 'Round': 105, 'Results_raw': {'train_avg_loss': 0.050663, 'train_total': 1347060, 'train_imp_ratio': 14.419663, 'train_loss': 68245.7079}}
# 2022-09-11 08:19:40,858 (client:259)INFO: {'Role': 'Client #7', 'Round': 105, 'Results_raw': {'train_avg_loss': 0.47159, 'train_total': 22280, 'train_imp_ratio': 26.896048, 'train_loss': 10507.018312}}
# 2022-09-11 08:19:40,861 (server:487)INFO: {'Role': 'Server #', 'Round': 105, 'Results_avg': {'test_avg_loss': 2.088128, 'test_total': 8350.846154, 'test_imp_ratio': -1041.892223, 'test_loss': 9225.802643, 'val_avg_loss': 0.471288, 'val_total': 8350.461538, 'val_imp_ratio': 11.317634, 'val_loss': 352.454352}}
# 2022-09-11 08:19:40,869 (server:386)INFO: Server #0: Final evaluation is finished! Starting merging results.
# 2022-09-11 08:19:40,870 (server:416)INFO: {'Role': 'Server #', 'Round': 'Final', 'Results_raw': {'client_best_individual': {}, 'client_summarized_avg': {}}}
# 2022-09-11 08:19:40,871 (server:437)INFO: {'Role': 'Client #1', 'Round': 121, 'Results_raw': {'test_avg_loss': 1.061215, 'test_total': 417, 'test_imp_ratio': -59.999981, 'test_loss': 442.526725, 'val_avg_loss': 0.199492, 'val_total': 416, 'val_imp_ratio': 67.19406, 'val_loss': 82.988604}}
# 2022-09-11 08:19:40,872 (server:437)INFO: {'Role': 'Client #2', 'Round': 121, 'Results_raw': {'test_avg_loss': 0.432945, 'test_total': 61, 'test_imp_ratio': 20.754584, 'test_loss': 26.409626, 'val_avg_loss': 0.616861, 'val_total': 60, 'val_imp_ratio': -9.339806, 'val_loss': 37.011688}}
# 2022-09-11 08:19:40,873 (server:437)INFO: {'Role': 'Client #3', 'Round': 121, 'Results_raw': {'test_avg_loss': 0.679375, 'test_total': 740, 'test_imp_ratio': -17.871189, 'test_loss': 502.73719, 'val_avg_loss': 0.547925, 'val_total': 740, 'val_imp_ratio': 23.193613, 'val_loss': 405.464631}}
# 2022-09-11 08:19:40,874 (server:437)INFO: {'Role': 'Client #4', 'Round': 121, 'Results_raw': {'test_avg_loss': 1.82533, 'test_total': 34, 'test_imp_ratio': -183.332672, 'test_loss': 62.061204, 'val_avg_loss': 0.467246, 'val_total': 34, 'val_imp_ratio': -33.333022, 'val_loss': 15.886379}}
# 2022-09-11 08:19:40,875 (server:437)INFO: {'Role': 'Client #5', 'Round': 121, 'Results_raw': {'test_avg_loss': 0.57082, 'test_total': 63, 'test_imp_ratio': 100.0, 'test_loss': 35.96164, 'val_avg_loss': 0.691635, 'val_total': 63, 'val_imp_ratio': -12.000112, 'val_loss': 43.572998}}
# 2022-09-11 08:19:40,876 (server:437)INFO: {'Role': 'Client #6', 'Round': 121, 'Results_raw': {'test_avg_loss': 1.365266, 'test_total': 367, 'test_imp_ratio': -232.292151, 'test_loss': 501.052633, 'val_avg_loss': 0.475942, 'val_total': 367, 'val_imp_ratio': 16.666545, 'val_loss': 174.670816}}
# 2022-09-11 08:19:40,877 (server:437)INFO: {'Role': 'Client #7', 'Round': 121, 'Results_raw': {'test_avg_loss': 0.923393, 'test_total': 743, 'test_imp_ratio': -71.809946, 'test_loss': 686.081188, 'val_avg_loss': 0.543362, 'val_total': 743, 'val_imp_ratio': 14.540131, 'val_loss': 403.718034}}
# 2022-09-11 08:19:40,878 (server:437)INFO: {'Role': 'Client #8', 'Round': 121, 'Results_raw': {'test_avg_loss': 3.924849, 'test_total': 260, 'test_imp_ratio': -320.000916, 'test_loss': 1020.460749, 'val_avg_loss': 0.400956, 'val_total': 259, 'val_imp_ratio': 54.369855, 'val_loss': 103.847725}}
# 2022-09-11 08:19:40,879 (server:437)INFO: {'Role': 'Client #9', 'Round': 121, 'Results_raw': {'test_avg_loss': 2.193565, 'test_total': 44902, 'test_imp_ratio': -3605.408692, 'test_loss': 98495.451759, 'val_avg_loss': 0.049557, 'val_total': 44902, 'val_imp_ratio': 16.287827, 'val_loss': 2225.197988}}
# 2022-09-11 08:19:40,880 (server:437)INFO: {'Role': 'Client #10', 'Round': 121, 'Results_raw': {'test_avg_loss': 0.164093, 'test_total': 36465, 'test_imp_ratio': -2216.715698, 'test_loss': 5983.650086, 'val_avg_loss': 0.007014, 'val_total': 36464, 'val_imp_ratio': 0.969682, 'val_loss': 255.770028}}
# 2022-09-11 08:19:40,881 (server:437)INFO: {'Role': 'Client #11', 'Round': 121, 'Results_raw': {'test_avg_loss': 6.003339, 'test_total': 756, 'test_imp_ratio': -717.881444, 'test_loss': 4538.524635, 'val_avg_loss': 0.538572, 'val_total': 756, 'val_imp_ratio': 26.626207, 'val_loss': 407.160233}}
# 2022-09-11 08:19:40,882 (server:437)INFO: {'Role': 'Client #12', 'Round': 121, 'Results_raw': {'test_avg_loss': 7.743785, 'test_total': 203, 'test_imp_ratio': -468.841364, 'test_loss': 1571.988383, 'val_avg_loss': 1.583714, 'val_total': 203, 'val_imp_ratio': -16.336097, 'val_loss': 321.493852}}
# 2022-09-11 08:19:40,883 (server:437)INFO: {'Role': 'Client #13', 'Round': 121, 'Results_raw': {'test_avg_loss': 0.257687, 'test_total': 23550, 'test_imp_ratio': -5771.199426, 'test_loss': 6068.528545, 'val_avg_loss': 0.004464, 'val_total': 23549, 'val_imp_ratio': -1.709645, 'val_loss': 105.123602}}
# 2022-09-11 08:19:40,885 (monitor:121)INFO: In worker #0, the system-related metrics are: {'id': 0, 'fl_end_time_minutes': 2795.849759, 'total_model_size': 0, 'total_flops': 0, 'total_upload_bytes': 17104568, 'total_download_bytes': 13290080, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.849509, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:40,890 (client:440)INFO: ================= client 1 received finish message =================
# 2022-09-11 08:19:41,057 (client:453)INFO: Client #1 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,058 (monitor:121)INFO: In worker #1, the system-related metrics are: {'id': 1, 'fl_end_time_minutes': 2795.852155, 'total_model_size': 304514, 'total_flops': 0, 'total_upload_bytes': 1031816, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.84936, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,059 (client:440)INFO: ================= client 2 received finish message =================
# 2022-09-11 08:19:41,090 (client:453)INFO: Client #2 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,091 (monitor:121)INFO: In worker #2, the system-related metrics are: {'id': 2, 'fl_end_time_minutes': 2795.852221, 'total_model_size': 278786, 'total_flops': 0, 'total_upload_bytes': 1031816, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.848861, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,092 (client:440)INFO: ================= client 3 received finish message =================
# 2022-09-11 08:19:41,351 (client:453)INFO: Client #3 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,352 (monitor:121)INFO: In worker #3, the system-related metrics are: {'id': 3, 'fl_end_time_minutes': 2795.856078, 'total_model_size': 497474, 'total_flops': 0, 'total_upload_bytes': 1031816, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.848379, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,353 (client:440)INFO: ================= client 4 received finish message =================
# 2022-09-11 08:19:41,376 (client:453)INFO: Client #4 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,377 (monitor:121)INFO: In worker #4, the system-related metrics are: {'id': 4, 'fl_end_time_minutes': 2795.856078, 'total_model_size': 111554, 'total_flops': 0, 'total_upload_bytes': 1031144, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.847963, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,377 (client:440)INFO: ================= client 5 received finish message =================
# 2022-09-11 08:19:41,418 (client:453)INFO: Client #5 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,419 (monitor:121)INFO: In worker #5, the system-related metrics are: {'id': 5, 'fl_end_time_minutes': 2795.856366, 'total_model_size': 253058, 'total_flops': 0, 'total_upload_bytes': 1031144, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.847548, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,420 (client:440)INFO: ================= client 6 received finish message =================
# 2022-09-11 08:19:41,555 (client:453)INFO: Client #6 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,556 (monitor:121)INFO: In worker #6, the system-related metrics are: {'id': 6, 'fl_end_time_minutes': 2795.858161, 'total_model_size': 304514, 'total_flops': 0, 'total_upload_bytes': 1031816, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.847066, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,557 (client:440)INFO: ================= client 7 received finish message =================
# 2022-09-11 08:19:41,845 (client:453)INFO: Client #7 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,846 (monitor:121)INFO: In worker #7, the system-related metrics are: {'id': 7, 'fl_end_time_minutes': 2795.862467, 'total_model_size': 510338, 'total_flops': 0, 'total_upload_bytes': 1031816, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.846534, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,847 (client:440)INFO: ================= client 8 received finish message =================
# 2022-09-11 08:19:41,945 (client:453)INFO: Client #8 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:41,946 (monitor:121)INFO: In worker #8, the system-related metrics are: {'id': 8, 'fl_end_time_minutes': 2795.863679, 'total_model_size': 265922, 'total_flops': 0, 'total_upload_bytes': 1031816, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.846085, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:41,946 (client:440)INFO: ================= client 9 received finish message =================
# 2022-09-11 08:19:57,109 (client:453)INFO: Client #9 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:19:57,110 (monitor:121)INFO: In worker #9, the system-related metrics are: {'id': 9, 'fl_end_time_minutes': 2796.115876, 'total_model_size': 381633, 'total_flops': 0, 'total_upload_bytes': 1032488, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.845536, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:19:57,111 (client:440)INFO: ================= client 10 received finish message =================
# 2022-09-11 08:20:09,413 (client:453)INFO: Client #10 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:20:09,414 (monitor:121)INFO: In worker #10, the system-related metrics are: {'id': 10, 'fl_end_time_minutes': 2796.32047, 'total_model_size': 99210, 'total_flops': 0, 'total_upload_bytes': 1032488, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.845071, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:20:09,415 (client:440)INFO: ================= client 11 received finish message =================
# 2022-09-11 08:20:09,693 (client:453)INFO: Client #11 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:20:09,694 (monitor:121)INFO: In worker #11, the system-related metrics are: {'id': 11, 'fl_end_time_minutes': 2796.324636, 'total_model_size': 304449, 'total_flops': 0, 'total_upload_bytes': 1032488, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.844572, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:20:09,695 (client:440)INFO: ================= client 12 received finish message =================
# 2022-09-11 08:20:09,772 (client:453)INFO: Client #12 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:20:09,773 (monitor:121)INFO: In worker #12, the system-related metrics are: {'id': 12, 'fl_end_time_minutes': 2796.325534, 'total_model_size': 304449, 'total_flops': 0, 'total_upload_bytes': 1031816, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.844141, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:20:09,774 (client:440)INFO: ================= client 13 received finish message =================
# 2022-09-11 08:20:17,907 (client:453)INFO: Client #13 finished saving prediction results in F:\python\FederatedScope\exp\FedAvg_gin_on_cikmcup_lr0.0001_lstep10_\sub_exp_20220909094212\prediction.csv
# 2022-09-11 08:20:17,908 (monitor:121)INFO: In worker #13, the system-related metrics are: {'id': 13, 'fl_end_time_minutes': 2796.460613, 'total_model_size': 163660, 'total_flops': 0, 'total_upload_bytes': 1032488, 'total_download_bytes': 1315736, 'global_convergence_round': 105, 'local_convergence_round': 0, 'global_convergence_time_minutes': 2795.843642, 'local_convergence_time_minutes': 0}
# 2022-09-11 08:20:17,910 (monitor:278)INFO: We will compress the file eval_results.raw into a .gz file, and delete the old one
# 2022-09-11 08:20:17,961 (monitor:195)INFO: After merging the system metrics from all works, we got avg: defaultdict(None, {'id': 'sys_avg', 'sys_avg/fl_end_time_minutes': 2796.018149, 'sys_avg/total_model_size': '263.64K', 'sys_avg/total_flops': '0.0', 'sys_avg/total_upload_bytes': '2.08M', 'sys_avg/total_download_bytes': '2.07M', 'sys_avg/global_convergence_round': 105.0, 'sys_avg/local_convergence_round': 0.0, 'sys_avg/global_convergence_time_minutes': 2795.846733, 'sys_avg/local_convergence_time_minutes': 0.0})
# 2022-09-11 08:20:17,962 (monitor:198)INFO: After merging the system metrics from all works, we got std: defaultdict(None, {'id': 'sys_std', 'sys_std/fl_end_time_minutes': 0.226934, 'sys_std/total_model_size': '134.51K', 'sys_std/total_flops': '0.0', 'sys_std/total_upload_bytes': '3.95M', 'sys_std/total_download_bytes': '2.94M', 'sys_std/global_convergence_round': 0.0, 'sys_std/local_convergence_round': 0.0, 'sys_std/global_convergence_time_minutes': 0.001885, 'sys_std/local_convergence_time_minutes': 0.0})

# %%
# Out:
# 2022-09-04 08:10:29,733 (utils:129)INFO: the current machine is at 10.77.112.1
# 2022-09-04 08:10:29,733 (utils:131)INFO: the current dir is F:\python\FederatedScope
# 2022-09-04 08:10:29,749 (utils:132)INFO: the output dir is exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# 2022-09-04 08:10:31,807 (cikm_cup:57)INFO: Loading CIKMCUP data from F:\python\FederatedScope\data\CIKM22Competition.
# 2022-09-04 08:10:31,814 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #1.
# 2022-09-04 08:10:32,163 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #2.
# 2022-09-04 08:10:32,218 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #3.
# 2022-09-04 08:10:32,594 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #4.
# 2022-09-04 08:10:32,639 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #5.
# 2022-09-04 08:10:32,693 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #6.
# 2022-09-04 08:10:33,004 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #7.
# 2022-09-04 08:10:33,391 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #8.
# 2022-09-04 08:10:33,566 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #9.
# 2022-09-04 08:11:06,199 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #10.
# 2022-09-04 08:11:34,969 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #11.
# 2022-09-04 08:11:37,620 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #12.
# 2022-09-04 08:11:37,742 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #13.
# 2022-09-04 08:11:56,740 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.004389
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 12
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,041 (fed_runner:249)INFO: Server #0 has been set up ...
# 2022-09-04 08:11:57,055 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.263789
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,080 (fed_runner:302)INFO: Client 1 has been set up ...
# 2022-09-04 08:11:57,096 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.289617
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,108 (fed_runner:302)INFO: Client 2 has been set up ...
# 2022-09-04 08:11:57,122 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.355404
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,137 (fed_runner:302)INFO: Client 3 has been set up ...
# 2022-09-04 08:11:57,152 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.176471
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,162 (fed_runner:302)INFO: Client 4 has been set up ...
# 2022-09-04 08:11:57,177 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.396825
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.0001
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,188 (fed_runner:302)INFO: Client 5 has been set up ...
# 2022-09-04 08:11:57,201 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.26158
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.0005
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,213 (fed_runner:302)INFO: Client 6 has been set up ...
# 2022-09-04 08:11:57,227 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.302378
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.01
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,242 (fed_runner:302)INFO: Client 7 has been set up ...
# 2022-09-04 08:11:57,256 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: CrossEntropyLoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.211538
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 2
#   task: graphClassification
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,268 (fed_runner:302)INFO: Client 8 has been set up ...
# 2022-09-04 08:11:57,284 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.059199
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,309 (fed_runner:302)INFO: Client 9 has been set up ...
# 2022-09-04 08:11:57,331 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.007083
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 10
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,347 (fed_runner:302)INFO: Client 10 has been set up ...
# 2022-09-04 08:11:57,367 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 0.734011
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
#   type: gin
#   use_bias: True
# nbafl:
#   use: False
# outdir: exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# personalization:
#   K: 5
#   beta: 1.0
#   local_param: ['encoder_atom', 'encoder', 'clf']
#   local_update_steps: 1
#   lr: 0.1
#   regular_weight: 0.1
#   share_non_trainable_para: False
# print_decimal_digits: 6
# regularizer:
#   mu: 0.0
#   type:
# seed: 0
# sgdmf:
#   use: False
# train:
#   batch_or_epoch: epoch
#   local_update_steps: 1
#   optimizer:
#     lr: 0.05
#     type: SGD
#     weight_decay: 0.0005
# trainer:
#   type: graphminibatch_trainer
# use_gpu: True
# verbose: 1
# vertical:
#   use: False
# wandb:
#   use: False
# 2022-09-04 08:11:57,386 (fed_runner:302)INFO: Client 11 has been set up ...
# 2022-09-04 08:11:57,405 (config:261)INFO: the used configs are:
# asyn:
#   min_received_num: 13
#   min_received_rate: -1.0
#   timeout: 0
#   use: True
# attack:
#   alpha_TV: 0.001
#   alpha_prop_loss: 0
#   attack_method:
#   attacker_id: -1
#   classifier_PIA: randomforest
#   info_diff_type: l2
#   inject_round: 0
#   max_ite: 400
#   reconstruct_lr: 0.01
#   reconstruct_optim: Adam
#   target_label_ind: -1
# backend: torch
# cfg_file:
# criterion:
#   type: MSELoss
# data:
#   args: []
#   batch_size: 64
#   cSBM_phi: [0.5, 0.5, 0.5]
#   consistent_label_distribution: False
#   drop_last: False
#   graphsaint:
#     num_steps: 30
#     walk_length: 2
#   loader:
#   num_workers: 0
#   pre_transform: []
#   quadratic:
#     dim: 1
#     max_curv: 12.5
#     min_curv: 0.02
#   root: data/
#   server_holds_all: False
#   shuffle: True
#   sizes: [10, 5]
#   splits: [0.8, 0.1, 0.1]
#   splitter:
#   splitter_args: []
#   subsample: 1.0
#   target_transform: []
#   transform: []
#   type: cikmcup
# device: 0
# distribute:
#   use: False
# early_stop:
#   delta: 0.0
#   improve_indicator_mode: mean
#   patience: 20
#   the_smaller_the_better: False
# eval:
#   base: 1.361326
#   best_res_update_round_wise_key: val_imp_ratio
#   count_flops: False
#   freq: 5
#   metrics: ['imp_ratio']
#   monitoring: []
#   report: ['avg']
#   save_data: False
#   split: ['test', 'val']
# expname: FedAvg_gin_on_cikmcup_lr0.1_lstep1_
# expname_tag:
# federate:
#   client_num: 13
#   data_weighted_aggr: False
#   ignore_weight: False
#   join_in_info: []
#   make_global_eval: False
#   method: FedAvg
#   mode: standalone
#   online_aggr: False
#   restore_from:
#   sample_client_num: 13
#   sample_client_rate: -1.0
#   sampler: uniform
#   save_to:
#   share_local_model: False
#   total_round_num: 120
#   unseen_clients_rate: 0.0
#   use_diff: False
#   use_ss: False
# fedopt:
#   optimizer:
#     lr: 0.01
#     type: SGD
#   use: True
# fedprox:
#   use: False
# fedsageplus:
#   a: 1.0
#   b: 1.0
#   c: 1.0
#   fedgen_epoch: 200
#   gen_hidden: 128
#   hide_portion: 0.5
#   loc_epoch: 1
#   num_pred: 5
# finetune:
#   batch_or_epoch: epoch
#   before_eval: False
#   freeze_param:
#   local_update_steps: 1
#   optimizer:
#     lr: 0.1
#     type: SGD
# flitplus:
#   factor_ema: 0.8
#   lambdavat: 0.5
#   tmpFed: 0.5
#   weightReg: 1.0
# gcflplus:
#   EPS_1: 0.05
#   EPS_2: 0.1
#   seq_length: 5
#   standardize: False
# grad:
#   grad_clip: 1.0
# hpo:
#   fedex:
#     cutoff: 0.0
#     diff: False
#     eta0: -1.0
#     flatten_ss: True
#     gamma: 0.0
#     num_arms: 16
#     sched: auto
#     ss:
#     use: False
#   init_cand_num: 16
#   larger_better: False
#   log_scale: False
#   metric: client_summarized_weighted_avg.val_loss
#   num_workers: 0
#   pbt:
#     max_stage: 5
#     perf_threshold: 0.1
#   plot_interval: 1
#   scheduler: rs
#   sha:
#     budgets: []
#     elim_rate: 3
#     elim_round_num: 3
#   ss:
#   table:
#     eps: 0.1
#     idx: 0
#     num: 27
#     ss:
#   working_folder: hpo
# model:
#   dropout: 0.5
#   embed_size: 8
#   graph_pooling: mean
#   hidden: 64
#   in_channels: 0
#   layer: 2
#   model_num_per_trainer: 1
#   num_item: 0
#   num_user: 0
#   out_channels: 1
#   task: graphRegression
# ...
# 2022-09-04 09:35:03,383 (client:259)INFO: {'Role': 'Client #7', 'Round': 33, 'Results_raw': {'train_total': 2228, 'train_loss': 1508.105318, 'train_avg_loss': 0.676887, 'train_imp_ratio': -45.465733}}
# 2022-09-04 09:35:03,461 (client:259)INFO: {'Role': 'Client #2', 'Round': 33, 'Results_raw': {'train_total': 181, 'train_loss': 121.954638, 'train_avg_loss': 0.673783, 'train_imp_ratio': -39.258026}}
# 2022-09-04 09:35:04,477 (client:259)INFO: {'Role': 'Client #11', 'Round': 33, 'Results_raw': {'train_total': 2268, 'train_loss': 3043.366943, 'train_avg_loss': 1.341873, 'train_imp_ratio': -82.813703}}
# 2022-09-04 09:35:04,524 (client:259)INFO: {'Role': 'Client #4', 'Round': 33, 'Results_raw': {'train_total': 101, 'train_loss': 67.261079, 'train_avg_loss': 0.665951, 'train_imp_ratio': -96.369179}}
# 2022-09-04 09:35:32,962 (client:259)INFO: {'Role': 'Client #13', 'Round': 33, 'Results_raw': {'train_total': 70648, 'train_loss': 415.863528, 'train_avg_loss': 0.005886, 'train_imp_ratio': -34.117474}}
# 2022-09-04 09:35:32,977 (server:321)INFO: ----------- Starting a new training round (Round #34) -------------
# 2022-09-04 09:35:33,446 (client:259)INFO: {'Role': 'Client #6', 'Round': 34, 'Results_raw': {'train_total': 1101, 'train_loss': 699.566174, 'train_avg_loss': 0.635392, 'train_imp_ratio': -2.777928}}
# 2022-09-04 09:35:34,541 (client:259)INFO: {'Role': 'Client #11', 'Round': 34, 'Results_raw': {'train_total': 2268, 'train_loss': 3050.233353, 'train_avg_loss': 1.3449, 'train_imp_ratio': -83.226155}}
# 2022-09-04 09:35:35,103 (client:259)INFO: {'Role': 'Client #1', 'Round': 34, 'Results_raw': {'train_total': 1249, 'train_loss': 754.268432, 'train_avg_loss': 0.603898, 'train_imp_ratio': -27.172996}}
# 2022-09-04 09:35:36,057 (client:259)INFO: {'Role': 'Client #3', 'Round': 34, 'Results_raw': {'train_total': 2219, 'train_loss': 1533.747024, 'train_avg_loss': 0.691188, 'train_imp_ratio': -34.408351}}
# 2022-09-04 09:35:36,369 (client:259)INFO: {'Role': 'Client #8', 'Round': 34, 'Results_raw': {'train_total': 777, 'train_loss': 343.309882, 'train_avg_loss': 0.44184, 'train_imp_ratio': 21.51615}}
# 2022-09-04 09:35:36,463 (client:259)INFO: {'Role': 'Client #5', 'Round': 34, 'Results_raw': {'train_total': 188, 'train_loss': 128.801553, 'train_avg_loss': 0.685115, 'train_imp_ratio': -8.574577}}
# 2022-09-04 09:35:36,541 (client:259)INFO: {'Role': 'Client #2', 'Round': 34, 'Results_raw': {'train_total': 181, 'train_loss': 121.385279, 'train_avg_loss': 0.670637, 'train_imp_ratio': -35.442738}}
# 2022-09-04 09:36:04,822 (client:259)INFO: {'Role': 'Client #13', 'Round': 34, 'Results_raw': {'train_total': 70648, 'train_loss': 415.923539, 'train_avg_loss': 0.005887, 'train_imp_ratio': -34.136858}}
# 2022-09-04 09:36:04,869 (client:259)INFO: {'Role': 'Client #4', 'Round': 34, 'Results_raw': {'train_total': 101, 'train_loss': 66.810739, 'train_avg_loss': 0.661492, 'train_imp_ratio': -96.369179}}
# 2022-09-04 09:36:05,135 (client:259)INFO: {'Role': 'Client #12', 'Round': 34, 'Results_raw': {'train_total': 608, 'train_loss': 3091.885147, 'train_avg_loss': 5.085337, 'train_imp_ratio': -273.557666}}
# 2022-09-04 09:36:48,498 (client:259)INFO: {'Role': 'Client #10', 'Round': 34, 'Results_raw': {'train_total': 109392, 'train_loss': 948.415513, 'train_avg_loss': 0.00867, 'train_imp_ratio': -22.404095}}
# 2022-09-04 09:37:45,109 (client:259)INFO: {'Role': 'Client #9', 'Round': 34, 'Results_raw': {'train_total': 134706, 'train_loss': 7524.000161, 'train_avg_loss': 0.055855, 'train_imp_ratio': 5.648791}}
# 2022-09-04 09:37:46,078 (client:259)INFO: {'Role': 'Client #7', 'Round': 34, 'Results_raw': {'train_total': 2228, 'train_loss': 1506.269549, 'train_avg_loss': 0.676064, 'train_imp_ratio': -46.207905}}
# 2022-09-04 09:37:46,078 (server:314)INFO: Server #0: Starting evaluation at the end of round 34.
# 2022-09-04 09:37:46,094 (server:321)INFO: ----------- Starting a new training round (Round #35) -------------
# 2022-09-04 09:38:59,329 (client:259)INFO: {'Role': 'Client #4', 'Round': 35, 'Results_raw': {'train_total': 101, 'train_loss': 67.03323, 'train_avg_loss': 0.663695, 'train_imp_ratio': -96.369179}}
# 2022-09-04 09:38:59,595 (client:259)INFO: {'Role': 'Client #12', 'Round': 35, 'Results_raw': {'train_total': 608, 'train_loss': 3051.862076, 'train_avg_loss': 5.01951, 'train_imp_ratio': -268.722098}}
# 2022-09-04 09:39:00,579 (client:259)INFO: {'Role': 'Client #7', 'Round': 35, 'Results_raw': {'train_total': 2228, 'train_loss': 1504.429958, 'train_avg_loss': 0.675238, 'train_imp_ratio': -46.05947}}
# 2022-09-04 09:39:01,141 (client:259)INFO: {'Role': 'Client #1', 'Round': 35, 'Results_raw': {'train_total': 1249, 'train_loss': 744.955159, 'train_avg_loss': 0.596441, 'train_imp_ratio': -24.441357}}
# 2022-09-04 09:39:01,641 (client:259)INFO: {'Role': 'Client #6', 'Round': 35, 'Results_raw': {'train_total': 1101, 'train_loss': 699.659299, 'train_avg_loss': 0.635476, 'train_imp_ratio': -2.083482}}
# 2022-09-04 09:39:01,719 (client:259)INFO: {'Role': 'Client #2', 'Round': 35, 'Results_raw': {'train_total': 181, 'train_loss': 122.390457, 'train_avg_loss': 0.67619, 'train_imp_ratio': -41.16567}}
# 2022-09-04 09:39:02,735 (client:259)INFO: {'Role': 'Client #11', 'Round': 35, 'Results_raw': {'train_total': 2268, 'train_loss': 3013.921267, 'train_avg_loss': 1.328889, 'train_imp_ratio': -81.044885}}
# 2022-09-04 09:39:45,785 (client:259)INFO: {'Role': 'Client #10', 'Round': 35, 'Results_raw': {'train_total': 109392, 'train_loss': 948.402219, 'train_avg_loss': 0.00867, 'train_imp_ratio': -22.402373}}
# 2022-09-04 09:39:45,863 (client:259)INFO: {'Role': 'Client #5', 'Round': 35, 'Results_raw': {'train_total': 188, 'train_loss': 128.895864, 'train_avg_loss': 0.685616, 'train_imp_ratio': -4.553296}}
# 2022-09-04 09:40:14,330 (client:259)INFO: {'Role': 'Client #13', 'Round': 35, 'Results_raw': {'train_total': 70648, 'train_loss': 414.264825, 'train_avg_loss': 0.005864, 'train_imp_ratio': -33.601916}}
# 2022-09-04 09:40:14,642 (client:259)INFO: {'Role': 'Client #8', 'Round': 35, 'Results_raw': {'train_total': 777, 'train_loss': 344.584344, 'train_avg_loss': 0.44348, 'train_imp_ratio': 21.51615}}
# 2022-09-04 09:40:15,611 (client:259)INFO: {'Role': 'Client #3', 'Round': 35, 'Results_raw': {'train_total': 2219, 'train_loss': 1530.888223, 'train_avg_loss': 0.6899, 'train_imp_ratio': -26.293129}}
# 2022-09-04 09:41:17,064 (client:259)INFO: {'Role': 'Client #9', 'Round': 35, 'Results_raw': {'train_total': 134706, 'train_loss': 7540.197443, 'train_avg_loss': 0.055975, 'train_imp_ratio': 5.445683}}
# 2022-09-04 09:41:17,064 (server:487)INFO: {'Role': 'Server #', 'Round': 35, 'Results_avg': {'test_total': 8350.846154, 'test_loss': 9534.043492, 'test_avg_loss': 1.249621, 'test_imp_ratio': -979.921001, 'val_total': 8350.461538, 'val_loss': 876.031846, 'val_avg_loss': 1.065525, 'val_imp_ratio': -85.157885}}
# 2022-09-04 09:41:17,079 (server:321)INFO: ----------- Starting a new training round (Round #36) -------------
# 2022-09-04 09:41:18,189 (client:259)INFO: {'Role': 'Client #7', 'Round': 36, 'Results_raw': {'train_total': 2228, 'train_loss': 1504.647741, 'train_avg_loss': 0.675336, 'train_imp_ratio': -45.614167}}
# 2022-09-04 09:41:18,799 (client:259)INFO: {'Role': 'Client #1', 'Round': 36, 'Results_raw': {'train_total': 1249, 'train_loss': 744.137168, 'train_avg_loss': 0.595786, 'train_imp_ratio': -25.958934}}
# 2022-09-04 09:41:19,854 (client:259)INFO: {'Role': 'Client #3', 'Round': 36, 'Results_raw': {'train_total': 2219, 'train_loss': 1534.741889, 'train_avg_loss': 0.691637, 'train_imp_ratio': -33.647549}}
# 2022-09-04 09:41:19,954 (client:259)INFO: {'Role': 'Client #5', 'Round': 36, 'Results_raw': {'train_total': 188, 'train_loss': 129.025495, 'train_avg_loss': 0.686306, 'train_imp_ratio': -12.595857}}
# 2022-09-04 09:42:20,480 (client:259)INFO: {'Role': 'Client #9', 'Round': 36, 'Results_raw': {'train_total': 134706, 'train_loss': 7550.790116, 'train_avg_loss': 0.056054, 'train_imp_ratio': 5.312842}}
# 2022-09-04 09:42:21,587 (client:259)INFO: {'Role': 'Client #11', 'Round': 36, 'Results_raw': {'train_total': 2268, 'train_loss': 3042.45338, 'train_avg_loss': 1.34147, 'train_imp_ratio': -82.758826}}
# 2022-09-04 09:42:52,456 (client:259)INFO: {'Role': 'Client #13', 'Round': 36, 'Results_raw': {'train_total': 70648, 'train_loss': 414.439795, 'train_avg_loss': 0.005866, 'train_imp_ratio': -33.658327}}
# 2022-09-04 09:42:52,700 (client:259)INFO: {'Role': 'Client #12', 'Round': 36, 'Results_raw': {'train_total': 608, 'train_loss': 3012.94957, 'train_avg_loss': 4.955509, 'train_imp_ratio': -264.020755}}
# 2022-09-04 09:42:53,193 (client:259)INFO: {'Role': 'Client #6', 'Round': 36, 'Results_raw': {'train_total': 1101, 'train_loss': 696.179401, 'train_avg_loss': 0.632316, 'train_imp_ratio': -2.083482}}
# 2022-09-04 09:42:53,240 (client:259)INFO: {'Role': 'Client #4', 'Round': 36, 'Results_raw': {'train_total': 101, 'train_loss': 67.784477, 'train_avg_loss': 0.671133, 'train_imp_ratio': -96.369179}}
# 2022-09-04 09:42:53,318 (client:259)INFO: {'Role': 'Client #2', 'Round': 36, 'Results_raw': {'train_total': 181, 'train_loss': 122.564065, 'train_avg_loss': 0.67715, 'train_imp_ratio': -39.258026}}
# 2022-09-04 09:42:53,662 (client:259)INFO: {'Role': 'Client #8', 'Round': 36, 'Results_raw': {'train_total': 777, 'train_loss': 341.403789, 'train_avg_loss': 0.439387, 'train_imp_ratio': 21.51615}}
# 2022-09-04 09:43:41,216 (client:259)INFO: {'Role': 'Client #10', 'Round': 36, 'Results_raw': {'train_total': 109392, 'train_loss': 946.70553, 'train_avg_loss': 0.008654, 'train_imp_ratio': -22.183408}}
# 2022-09-04 09:43:41,230 (server:321)INFO: ----------- Starting a new training round (Round #37) -------------
# 2022-09-04 09:43:41,566 (client:259)INFO: {'Role': 'Client #8', 'Round': 37, 'Results_raw': {'train_total': 777, 'train_loss': 341.901784, 'train_avg_loss': 0.440028, 'train_imp_ratio': 21.51615}}
# 2022-09-04 09:43:41,834 (client:259)INFO: {'Role': 'Client #12', 'Round': 37, 'Results_raw': {'train_total': 608, 'train_loss': 2945.553375, 'train_avg_loss': 4.84466, 'train_imp_ratio': -255.878005}}
# 2022-09-04 09:43:42,873 (client:259)INFO: {'Role': 'Client #7', 'Round': 37, 'Results_raw': {'train_total': 2228, 'train_loss': 1502.866691, 'train_avg_loss': 0.674536, 'train_imp_ratio': -43.981389}}
# 2022-09-04 09:44:29,749 (client:259)INFO: {'Role': 'Client #10', 'Round': 37, 'Results_raw': {'train_total': 109392, 'train_loss': 943.671449, 'train_avg_loss': 0.008627, 'train_imp_ratio': -21.791774}}
# 2022-09-04 09:44:30,887 (client:259)INFO: {'Role': 'Client #3', 'Round': 37, 'Results_raw': {'train_total': 2219, 'train_loss': 1533.843706, 'train_avg_loss': 0.691232, 'train_imp_ratio': -32.125945}}
# 2022-09-04 09:45:01,628 (client:259)INFO: {'Role': 'Client #13', 'Round': 37, 'Results_raw': {'train_total': 70648, 'train_loss': 412.903722, 'train_avg_loss': 0.005845, 'train_imp_ratio': -33.162916}}
# 2022-09-04 09:45:02,191 (client:259)INFO: {'Role': 'Client #1', 'Round': 37, 'Results_raw': {'train_total': 1249, 'train_loss': 749.766548, 'train_avg_loss': 0.600293, 'train_imp_ratio': -28.387058}}
# 2022-09-04 09:45:02,762 (client:259)INFO: {'Role': 'Client #6', 'Round': 37, 'Results_raw': {'train_total': 1101, 'train_loss': 694.177874, 'train_avg_loss': 0.630498, 'train_imp_ratio': -2.083482}}
# 2022-09-04 09:45:04,154 (client:259)INFO: {'Role': 'Client #11', 'Round': 37, 'Results_raw': {'train_total': 2268, 'train_loss': 3037.727746, 'train_avg_loss': 1.339386, 'train_imp_ratio': -82.474936}}
# 2022-09-04 09:45:04,258 (client:259)INFO: {'Role': 'Client #2', 'Round': 37, 'Results_raw': {'train_total': 181, 'train_loss': 122.614336, 'train_avg_loss': 0.677427, 'train_imp_ratio': -39.258026}}
# 2022-09-04 09:45:04,356 (client:259)INFO: {'Role': 'Client #5', 'Round': 37, 'Results_raw': {'train_total': 188, 'train_loss': 130.202851, 'train_avg_loss': 0.692568, 'train_imp_ratio': -15.276711}}
# 2022-09-04 09:46:06,723 (client:259)INFO: {'Role': 'Client #9', 'Round': 37, 'Results_raw': {'train_total': 134706, 'train_loss': 7570.974507, 'train_avg_loss': 0.056204, 'train_imp_ratio': 5.059738}}
# 2022-09-04 09:46:06,787 (client:259)INFO: {'Role': 'Client #4', 'Round': 37, 'Results_raw': {'train_total': 101, 'train_loss': 67.209551, 'train_avg_loss': 0.665441, 'train_imp_ratio': -96.369179}}
# 2022-09-04 09:46:06,801 (server:321)INFO: ----------- Starting a new training round (Round #38) -------------
# 2022-09-04 09:46:07,142 (client:259)INFO: {'Role': 'Client #8', 'Round': 38, 'Results_raw': {'train_total': 777, 'train_loss': 344.462633, 'train_avg_loss': 0.443324, 'train_imp_ratio': 21.51615}}
# 2022-09-04 09:46:08,122 (client:259)INFO: {'Role': 'Client #3', 'Round': 38, 'Results_raw': {'train_total': 2219, 'train_loss': 1531.401341, 'train_avg_loss': 0.690131, 'train_imp_ratio': -33.901149}}
# 2022-09-04 09:46:09,155 (client:259)INFO: {'Role': 'Client #11', 'Round': 38, 'Results_raw': {'train_total': 2268, 'train_loss': 2990.535532, 'train_avg_loss': 1.318578, 'train_imp_ratio': -79.64012}}
# 2022-09-04 09:46:09,654 (client:259)INFO: {'Role': 'Client #6', 'Round': 38, 'Results_raw': {'train_total': 1101, 'train_loss': 695.646819, 'train_avg_loss': 0.631832, 'train_imp_ratio': -2.430705}}
# 2022-09-04 09:46:09,708 (client:259)INFO: {'Role': 'Client #4', 'Round': 38, 'Results_raw': {'train_total': 101, 'train_loss': 66.738595, 'train_avg_loss': 0.660778, 'train_imp_ratio': -96.369179}}
# 2022-09-04 09:47:00,020 (client:259)INFO: {'Role': 'Client #10', 'Round': 38, 'Results_raw': {'train_total': 109392, 'train_loss': 943.621491, 'train_avg_loss': 0.008626, 'train_imp_ratio': -21.785357}}
# 2022-09-04 09:47:00,116 (client:259)INFO: {'Role': 'Client #2', 'Round': 38, 'Results_raw': {'train_total': 181, 'train_loss': 121.682671, 'train_avg_loss': 0.67228, 'train_imp_ratio': -43.073314}}
# 2022-09-04 09:47:01,196 (client:259)INFO: {'Role': 'Client #7', 'Round': 38, 'Results_raw': {'train_total': 2228, 'train_loss': 1506.819768, 'train_avg_loss': 0.67631, 'train_imp_ratio': -45.02043}}
# 2022-09-04 09:47:32,236 (client:259)INFO: {'Role': 'Client #13', 'Round': 38, 'Results_raw': {'train_total': 70648, 'train_loss': 412.401763, 'train_avg_loss': 0.005837, 'train_imp_ratio': -33.001054}}
# 2022-09-04 09:48:33,505 (client:259)INFO: {'Role': 'Client #9', 'Round': 38, 'Results_raw': {'train_total': 134706, 'train_loss': 7534.343773, 'train_avg_loss': 0.055932, 'train_imp_ratio': 5.519077}}
# 2022-09-04 09:48:33,769 (client:259)INFO: {'Role': 'Client #12', 'Round': 38, 'Results_raw': {'train_total': 608, 'train_loss': 2967.918762, 'train_avg_loss': 4.881445, 'train_imp_ratio': -258.580194}}
# 2022-09-04 09:48:34,360 (client:259)INFO: {'Role': 'Client #1', 'Round': 38, 'Results_raw': {'train_total': 1249, 'train_loss': 742.769093, 'train_avg_loss': 0.594691, 'train_imp_ratio': -25.351903}}
# 2022-09-04 09:48:34,457 (client:259)INFO: {'Role': 'Client #5', 'Round': 38, 'Results_raw': {'train_total': 188, 'train_loss': 128.90083, 'train_avg_loss': 0.685643, 'train_imp_ratio': -3.212869}}
# 2022-09-04 09:48:34,472 (server:321)INFO: ----------- Starting a new training round (Round #39) -------------
# 2022-09-04 09:48:34,976 (client:259)INFO: {'Role': 'Client #6', 'Round': 39, 'Results_raw': {'train_total': 1101, 'train_loss': 693.992673, 'train_avg_loss': 0.630329, 'train_imp_ratio': -2.083482}}
# 2022-09-04 09:49:36,781 (client:259)INFO: {'Role': 'Client #9', 'Round': 39, 'Results_raw': {'train_total': 134706, 'train_loss': 7510.351044, 'train_avg_loss': 0.055754, 'train_imp_ratio': 5.819955}}
# 2022-09-04 09:49:37,377 (client:259)INFO: {'Role': 'Client #1', 'Round': 39, 'Results_raw': {'train_total': 1249, 'train_loss': 745.340712, 'train_avg_loss': 0.59675, 'train_imp_ratio': -20.799171}}
# 2022-09-04 09:49:38,365 (client:259)INFO: {'Role': 'Client #7', 'Round': 39, 'Results_raw': {'train_total': 2228, 'train_loss': 1503.961995, 'train_avg_loss': 0.675028, 'train_imp_ratio': -47.246946}}
