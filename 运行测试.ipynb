# %%
# %run federatedscope/main.py --cfg federatedscope\gfl\baseline\fedavg_gin_minibatch_on_cikmcup.yaml  --client_cfg federatedscope/gfl/baseline/fedavg_gin_minibatch_on_cikmcup_per_client.yaml fedopt.use True
# Out:
# 2022-09-04 09:50:11,374 (utils:129)INFO: the current machine is at 10.77.112.1
# 2022-09-04 09:50:11,374 (utils:131)INFO: the current dir is F:\python\FederatedScope
# 2022-09-04 09:50:11,374 (utils:132)INFO: the output dir is exp\FedAvg_gin_on_cikmcup_lr0.1_lstep10_\sub_exp_20220904095011
# 2022-09-04 09:50:13,392 (cikm_cup:57)INFO: Loading CIKMCUP data from F:\python\FederatedScope\data\CIKM22Competition.
# 2022-09-04 09:50:13,392 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #1.
# 2022-09-04 09:50:14,032 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #2.
# 2022-09-04 09:50:14,071 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #3.
# 2022-09-04 09:50:14,801 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #4.
# 2022-09-04 09:50:14,837 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #5.
# 2022-09-04 09:50:14,873 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #6.
# 2022-09-04 09:50:15,250 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #7.
# ...

# %%
# %run federatedscope/main.py --cfg F:\python\FederatedScope\cfg\fedavg_gin_config.yaml --client_cfg federatedscope/gfl/baseline/fedavg_gin_minibatch_on_cikmcup_per_client.yaml fedopt.use True
# Out:
# 2022-09-04 08:10:29,733 (utils:129)INFO: the current machine is at 10.77.112.1
# 2022-09-04 08:10:29,733 (utils:131)INFO: the current dir is F:\python\FederatedScope
# 2022-09-04 08:10:29,749 (utils:132)INFO: the output dir is exp\FedAvg_gin_on_cikmcup_lr0.1_lstep1_\sub_exp_20220904081029
# 2022-09-04 08:10:31,807 (cikm_cup:57)INFO: Loading CIKMCUP data from F:\python\FederatedScope\data\CIKM22Competition.
# 2022-09-04 08:10:31,814 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #1.
# 2022-09-04 08:10:32,163 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #2.
# 2022-09-04 08:10:32,218 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #3.
# 2022-09-04 08:10:32,594 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #4.
# 2022-09-04 08:10:32,639 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #5.
# 2022-09-04 08:10:32,693 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #6.
# 2022-09-04 08:10:33,004 (cikm_cup:67)INFO: Loading CIKMCUP data for Client #7.
# ...
